# %%
from langchain_community.tools import ArxivQueryRun, WikipediaQueryRun
from langchain_community.utilities import ArxivAPIWrapper, WikipediaAPIWrapper

# %%
#use inbuilt tool 
api_wrapper_wiki = WikipediaAPIWrapper(top_k_results=1, doc_content_chars_max=250)
wiki=WikipediaQueryRun(api_wrapper=api_wrapper_wiki)

api_wrapper_arxiv = ArxivAPIWrapper(top_k_results=1, doc_content_chars_max=250)
arxiv=ArxivQueryRun(api_wrapper=api_wrapper_arxiv)
arxiv, wiki
# Out:
# (ArxivQueryRun(api_wrapper=ArxivAPIWrapper(arxiv_search=<class 'arxiv.Search'>, arxiv_exceptions=(<class 'arxiv.ArxivError'>, <class 'arxiv.UnexpectedEmptyPageError'>, <class 'arxiv.HTTPError'>), top_k_results=1, ARXIV_MAX_QUERY_LENGTH=300, continue_on_failure=False, load_max_docs=100, load_all_available_meta=False, doc_content_chars_max=250)),
#  WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper(wiki_client=<module 'wikipedia' from '/Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/wikipedia/__init__.py'>, top_k_results=1, lang='en', load_all_available_meta=False, doc_content_chars_max=250)))

# %%
tools=[wiki, arxiv]

# %%
#custom tools(RAG Tool)
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
loader=WebBaseLoader("https://docs.smith.langchain.com/")
docs=loader.load()
documents=RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200).split_documents(docs)
vectordb= FAISS.from_documents(documents, OpenAIEmbeddings)
retriever= vectordb.as_retriever()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 loader=WebBaseLoader("https://docs.smith.langchain.com/")
#       2 docs=loader.load()
#       3 documents=RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200).split_documents(docs)
# ----> 4 vectordb= FAISS.from_documents(documents, OpenAIEmbeddings)
#       5 retriever= vectordb.as_retriever()
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/langchain_core/vectorstores/base.py:814, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     811     if any(ids):
#     812         kwargs["ids"] = ids
# --> 814 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/langchain_community/vectorstores/faiss.py:1043, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#    1016 @classmethod
#    1017 def from_texts(
#    1018     cls,
#    (...)   1023     **kwargs: Any,
#    1024 ) -> FAISS:
#    1025     """Construct FAISS wrapper from raw documents.
#    1026
#    1027     This is a user friendly interface that:
#    (...)   1041             faiss = FAISS.from_texts(texts, embeddings)
#    1042     """
# -> 1043     embeddings = embedding.embed_documents(texts)
#    1044     return cls.__from(
#    1045         texts,
#    1046         embeddings,
#    (...)   1050         **kwargs,
#    1051     )
#
# TypeError: OpenAIEmbeddings.embed_documents() missing 1 required positional argument: 'texts'

# %%
from langchain_core.tools import create_retriever_tool

# %%
retriever_tool =create_retriever_tool(retriever, "langsmith-search", "search any info about langsmith")
retriever_tool.name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 retriever_tool =create_retriever_tool(retriever, "langsmith-search", "search any info about langsmith")
#       2 retriever_tool.name
#
# NameError: name 'retriever' is not defined

# %%
tools=[wiki, arxiv, retriever_tool]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 tools=[wiki, arxiv, retriever_tool]
#
# NameError: name 'retriever_tool' is not defined

# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv
import openai
load_dotenv()
import os

groq_api_key=os.getenv("GROQ_API_KEY")
openai_api_key =os.getenv("OPENAI_API_KEY")

# %%
pip install langchainhub
# Out:
# Collecting langchainhub
#   Downloading langchainhub-0.1.21-py3-none-any.whl.metadata (659 bytes)
# Collecting packaging<25,>=23.2 (from langchainhub)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: requests<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from langchainhub) (2.33.1)
# Collecting types-requests<3.0.0.0,>=2.31.0.2 (from langchainhub)
#   Downloading types_requests-2.33.0.20260408-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests<3,>=2->langchainhub) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests<3,>=2->langchainhub) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests<3,>=2->langchainhub) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests<3,>=2->langchainhub) (2026.4.22)
# Downloading langchainhub-0.1.21-py3-none-any.whl (5.2 kB)
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
# Downloading types_requests-2.33.0.20260408-py3-none-any.whl (20 kB)
# Installing collected packages: types-requests, packaging, langchainhub
#   Attempting uninstall: packaging
#     Found existing installation: packaging 26.1
#     Uninstalling packaging-26.1:
#       Successfully uninstalled packaging-26.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [langchainhub]
# Successfully installed langchainhub-0.1.21 packaging-24.2 types-requests-2.33.0.20260408
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain import hub
prompt=hub.pull("hwchase17/openai-functions-agent")
prompt.messages
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 from langchain import hub
#       2 prompt=hub.pull("hwchase17/openai-functions-agent")
#       3 prompt.messages
#
# ImportError: cannot import name 'hub' from 'langchain' (/Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/langchain/__init__.py)

# %%
#agents
from langchain_classic.agents import create_openai_tools_agent
agent=create_openai_tools_agent(llm, tools, prompt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 #agents
#       2 from langchain_classic.agents import create_openai_tools_agent
# ----> 3 agent=create_openai_tools_agent(llm, tools, prompt)
#
# NameError: name 'llm' is not defined

# %%
#agent executor
from langchain_classic.agents import AgentExecutor
agent_executor= AgentExecutor(agent=agent, tools=tools, verbose=True)
agent_executor
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 #agent executor
#       2 from langchain_classic.agents import AgentExecutor
# ----> 3 agent_executor= AgentExecutor(agent=agent, tools=tools, verbose=True)
#       4 agent_executor
#
# NameError: name 'agent' is not defined

# %%
agent_executor.invoke({"input: Tell me about langsmith"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 agent_executor.invoke({"input: Tell me about langsmith"})
#
# NameError: name 'agent_executor' is not defined
